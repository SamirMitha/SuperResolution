# %%
# install required package
# !pip install basicsr

# download packaged code from Google Drive
# !gdown --id 1RwJtkv5BmBw_NF-qycFtOmMY4jK6KXP4

# uncompressed packaged code
# !unzip test.zip

# %%
# evaluate ESRGANplus
# !python /content/test/codes/ESRGANplus/test.py -opt /content/test/options/test/ESRGANplus/test_ESRGANplus.json

# %%
# evaluate SRGAN
# !python /content/test/codes/SRGAN/test.py -opt /content/test/options/test/SRGAN/test_MSRGAN_x4.yml

# %%
# evaluate ESRGAN
# !python /content/test/codes/ESRGAN/test.py -opt /content/test/options/test/ESRGAN/test_ESRGAN_x4.yml

# %%
# evaluate FA-SRGAN
# !python /content/test/codes/FA-SRGAN/test.py -opt /content/test/options/test/FA-SRGAN/test_FASRGAN.json

# %%
from google.colab import files

# compress folder and download results
# !zip -r '/content/results.zip' '/content/test/results'
files.download("/content/results.zip")
